# %% [markdown]
# # Using, manipulating and visualizing time-series causal graphs

# %%
import networkx as nx
import numpy as np
import pandas as pd

import pywhy_graphs
from pywhy_graphs import CPDAG, PAG
from pywhy_graphs.viz import draw_tsgraph

from pywhy_graphs.classes.timeseries.timeseries import (
    StationaryTimeSeriesDiGraph,
    StationaryTimeSeriesGraph,
    StationaryTimeSeriesMixedEdgeGraph,
    complete_ts_graph,
    empty_ts_graph,
    nodes_in_time_order,
)

# %%
variables = ["x", "y", "z"]
max_lag = 3

G = empty_ts_graph(variables=variables, max_lag=max_lag, create_using=StationaryTimeSeriesDiGraph)

# %%
draw_tsgraph(G)
